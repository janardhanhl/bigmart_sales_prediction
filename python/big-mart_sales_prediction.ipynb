# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train=pd.read_csv("../train_v9rqX0R.csv")
test=pd.read_csv("../test_AbJTz2l.csv")

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
plt.figure(figsize=(12,15))
plt.subplot(3,2,1)
sns.histplot(train.Item_Fat_Content, stat='density')
plt.subplot(3,2,2)
sns.histplot(x=train.Item_Type,stat='density')
plt.subplot(3,2,3)
sns.histplot(train.Outlet_Size, stat='density')
plt.subplot(3,2,4)
sns.histplot(train.Outlet_Location_Type, stat='density')
plt.subplot(3,2,5)
sns.histplot(train.Outlet_Type, stat='density')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
sns.boxplot(train.Item_Weight)
plt.subplot(3,2,2)
sns.scatterplot(train.Item_Visibility)
plt.subplot(3,2,3)
sns.histplot(train.Item_MRP)
plt.subplot(3,2,4)
sns.swarmplot(x=train.Outlet_Establishment_Year,y=train.Item_Outlet_Sales)
plt.show()
# Out:
# /home/catalyst/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3544: UserWarning: 91.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/catalyst/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3544: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/catalyst/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3544: UserWarning: 90.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/catalyst/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3544: UserWarning: 96.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
